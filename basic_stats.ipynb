# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset_1=pd.read_csv('/content/trial_chr1_1 - Sheet1.csv',names=['chr','start','end','name','score','sign'])
dataset_2=pd.read_excel('/content/trial_chr1_2.xlsx',names=['chr','start','end','name','score','sign'])
dataset_3=pd.read_excel('/content/trial_chr1_3.xlsx',names=['chr','start','end','name','score','sign'])
dataset_4=pd.read_csv('/content/trial_chr1_4 - Sheet1.csv',names=['chr','start','end','name','score','sign'])
dataset_6=pd.read_csv('/content/trial_chr1_6 - Sheet1.csv',names=['chr','start','end','name','score','sign'])
dataset_7=pd.read_excel('/content/trial_sub_chr1_1.xlsx',names=['chr','start','end','name','score','sign'])
dataset_8=pd.read_excel('/content/trial_sub_chr1_2.xlsx',names=['chr','start','end','name','score','sign'])
dataset_9=pd.read_excel('/content/trial_sub_chr1_3.xlsx',names=['chr','start','end','name','score','sign'])
dataset_10=pd.read_excel('/content/trial_sub_chr1_4.xlsx',names=['chr','start','end','name','score','sign'])

# %%
len=249250621

# %%
dataset_1['start']=(dataset_1['start']/len)*100
dataset_1['end']=(dataset_1['end']/len)*100
dataset_2['start']=(dataset_2['start']/len)*100
dataset_2['end']=(dataset_2['end']/len)*100
dataset_3['start']=(dataset_3['start']/len)*100
dataset_3['end']=(dataset_3['end']/len)*100
dataset_4['start']=(dataset_4['start']/len)*100
dataset_4['end']=(dataset_4['end']/len)*100
dataset_6['start']=(dataset_6['start']/len)*100
dataset_6['end']=(dataset_6['end']/len)*100
dataset_1['start']=(dataset_7['start']/len)*100
dataset_1['end']=(dataset_7['end']/len)*100
dataset_2['start']=(dataset_8['start']/len)*100
dataset_2['end']=(dataset_8['end']/len)*100
dataset_3['start']=(dataset_9['start']/len)*100
dataset_3['end']=(dataset_9['end']/len)*100
dataset_4['start']=(dataset_10['start']/len)*100
dataset_4['end']=(dataset_10['end']/len)*100

# %%
L=[0]*10
plt.figure(figsize=(15,8))
for rows in dataset_1.iterrows():
  if(rows[1][2]<10):
    diff=rows[1][2]-rows[1][1]
    L[0]+=((diff/10)*100)
  elif(rows[1][2]<20): 
    diff=rows[1][2]-rows[1][1]
    L[1]+=((diff/10)*100)
  elif(rows[1][2]<30):  
    diff=rows[1][2]-rows[1][1]
    L[2]+=((diff/10)*100)
  elif(rows[1][2]<40):  
    diff=rows[1][2]-rows[1][1]
    L[3]+=((diff/10)*100)
  elif(rows[1][2]<50):  
    diff=rows[1][2]-rows[1][1]
    L[4]+=((diff/10)*100)
  elif(rows[1][2]<60):  
    diff=rows[1][2]-rows[1][1]
    L[5]+=((diff/10)*100)
  elif(rows[1][2]<70):  
    diff=rows[1][2]-rows[1][1]
    L[6]+=((diff/10)*100)
  elif(rows[1][2]<80):  
    diff=rows[1][2]-rows[1][1]
    L[7]+=((diff/10)*100)                        
  elif(rows[1][2]<90):  
    diff=rows[1][2]-rows[1][1]
    L[8]+=((diff/10)*100) 
  elif(rows[1][2]<100):  
    diff=rows[1][2]-rows[1][1]
    L[9]+=((diff/10)*100)       
x=[i for i in range(1,11,1)]
plt.plot(x,L,label='mef2c+alu')


L=[0]*10
for rows in dataset_2.iterrows():
  if(rows[1][2]<10):
    diff=rows[1][2]-rows[1][1]
    L[0]+=((diff/10)*100)
  elif(rows[1][2]<20): 
    diff=rows[1][2]-rows[1][1]
    L[1]+=((diff/10)*100)
  elif(rows[1][2]<30):  
    diff=rows[1][2]-rows[1][1]
    L[2]+=((diff/10)*100)
  elif(rows[1][2]<40):  
    diff=rows[1][2]-rows[1][1]
    L[3]+=((diff/10)*100)
  elif(rows[1][2]<50):  
    diff=rows[1][2]-rows[1][1]
    L[4]+=((diff/10)*100)
  elif(rows[1][2]<60):  
    diff=rows[1][2]-rows[1][1]
    L[5]+=((diff/10)*100)
  elif(rows[1][2]<70):  
    diff=rows[1][2]-rows[1][1]
    L[6]+=((diff/10)*100)
  elif(rows[1][2]<80):  
    diff=rows[1][2]-rows[1][1]
    L[7]+=((diff/10)*100)                        
  elif(rows[1][2]<90):  
    diff=rows[1][2]-rows[1][1]
    L[8]+=((diff/10)*100) 
  elif(rows[1][2]<100):  
    diff=rows[1][2]-rows[1][1]
    L[9]+=((diff/10)*100)
x=[i for i in range(1,11,1)]
plt.plot(x,L,label='mef2c+genic')
L=[0]*10
for rows in dataset_3.iterrows():
  if(rows[1][2]<10):
    diff=rows[1][2]-rows[1][1]
    L[0]+=((diff/10)*100)
  elif(rows[1][2]<20): 
    diff=rows[1][2]-rows[1][1]
    L[1]+=((diff/10)*100)
  elif(rows[1][2]<30):  
    diff=rows[1][2]-rows[1][1]
    L[2]+=((diff/10)*100)
  elif(rows[1][2]<40):  
    diff=rows[1][2]-rows[1][1]
    L[3]+=((diff/10)*100)
  elif(rows[1][2]<50):  
    diff=rows[1][2]-rows[1][1]
    L[4]+=((diff/10)*100)
  elif(rows[1][2]<60):  
    diff=rows[1][2]-rows[1][1]
    L[5]+=((diff/10)*100)
  elif(rows[1][2]<70):  
    diff=rows[1][2]-rows[1][1]
    L[6]+=((diff/10)*100)
  elif(rows[1][2]<80):  
    diff=rows[1][2]-rows[1][1]
    L[7]+=((diff/10)*100)                        
  elif(rows[1][2]<90):  
    diff=rows[1][2]-rows[1][1]
    L[8]+=((diff/10)*100) 
  elif(rows[1][2]<100):  
    diff=rows[1][2]-rows[1][1]
    L[9]+=((diff/10)*100)
x=[i for i in range(1,11,1)]
plt.plot(x,L,label='mef2c+intergenic')
L=[0]*10
for rows in dataset_4.iterrows():
  if(rows[1][2]<10):
    diff=rows[1][2]-rows[1][1]
    L[0]+=((diff/10)*100)
  elif(rows[1][2]<20): 
    diff=rows[1][2]-rows[1][1]
    L[1]+=((diff/10)*100)
  elif(rows[1][2]<30):  
    diff=rows[1][2]-rows[1][1]
    L[2]+=((diff/10)*100)
  elif(rows[1][2]<40):  
    diff=rows[1][2]-rows[1][1]
    L[3]+=((diff/10)*100)
  elif(rows[1][2]<50):  
    diff=rows[1][2]-rows[1][1]
    L[4]+=((diff/10)*100)
  elif(rows[1][2]<60):  
    diff=rows[1][2]-rows[1][1]
    L[5]+=((diff/10)*100)
  elif(rows[1][2]<70):  
    diff=rows[1][2]-rows[1][1]
    L[6]+=((diff/10)*100)
  elif(rows[1][2]<80):  
    diff=rows[1][2]-rows[1][1]
    L[7]+=((diff/10)*100)                        
  elif(rows[1][2]<90):  
    diff=rows[1][2]-rows[1][1]
    L[8]+=((diff/10)*100) 
  elif(rows[1][2]<100):  
    diff=rows[1][2]-rows[1][1]
    L[9]+=((diff/10)*100)
x=[i for i in range(1,11,1)]
plt.plot(x,L,label='mef2c+promotor')
L=[0]*10
for rows in dataset_6.iterrows():
  if(rows[1][2]<10):
    diff=rows[1][2]-rows[1][1]
    L[0]+=((diff/10)*100)
  elif(rows[1][2]<20): 
    diff=rows[1][2]-rows[1][1]
    L[1]+=((diff/10)*100)
  elif(rows[1][2]<30):  
    diff=rows[1][2]-rows[1][1]
    L[2]+=((diff/10)*100)
  elif(rows[1][2]<40):  
    diff=rows[1][2]-rows[1][1]
    L[3]+=((diff/10)*100)
  elif(rows[1][2]<50):  
    diff=rows[1][2]-rows[1][1]
    L[4]+=((diff/10)*100)
  elif(rows[1][2]<60):  
    diff=rows[1][2]-rows[1][1]
    L[5]+=((diff/10)*100)
  elif(rows[1][2]<70):  
    diff=rows[1][2]-rows[1][1]
    L[6]+=((diff/10)*100)
  elif(rows[1][2]<80):  
    diff=rows[1][2]-rows[1][1]
    L[7]+=((diff/10)*100)                        
  elif(rows[1][2]<90):  
    diff=rows[1][2]-rows[1][1]
    L[8]+=((diff/10)*100) 
  elif(rows[1][2]<100):  
    diff=rows[1][2]-rows[1][1]
    L[9]+=((diff/10)*100)                 
x=[i for i in range(1,11,1)]
plt.plot(x,L,label='mef2c+alu+intergenic')

L=[0]*10
for rows in dataset_8.iterrows():
  if(rows[1][2]<10):
    diff=rows[1][2]-rows[1][1]
    L[0]+=((diff/10)*100)
  elif(rows[1][2]<20): 
    diff=rows[1][2]-rows[1][1]
    L[1]+=((diff/10)*100)
  elif(rows[1][2]<30):  
    diff=rows[1][2]-rows[1][1]
    L[2]+=((diff/10)*100)
  elif(rows[1][2]<40):  
    diff=rows[1][2]-rows[1][1]
    L[3]+=((diff/10)*100)
  elif(rows[1][2]<50):  
    diff=rows[1][2]-rows[1][1]
    L[4]+=((diff/10)*100)
  elif(rows[1][2]<60):  
    diff=rows[1][2]-rows[1][1]
    L[5]+=((diff/10)*100)
  elif(rows[1][2]<70):  
    diff=rows[1][2]-rows[1][1]
    L[6]+=((diff/10)*100)
  elif(rows[1][2]<80):  
    diff=rows[1][2]-rows[1][1]
    L[7]+=((diff/10)*100)                        
  elif(rows[1][2]<90):  
    diff=rows[1][2]-rows[1][1]
    L[8]+=((diff/10)*100) 
  elif(rows[1][2]<100):  
    diff=rows[1][2]-rows[1][1]
    L[9]+=((diff/10)*100)
x=[i for i in range(1,11,1)]
plt.plot(x,L,label='mef2c-Alu+genic')

L=[0]*10
for rows in dataset_9.iterrows():
  if(rows[1][2]<10):
    diff=rows[1][2]-rows[1][1]
    L[0]+=((diff/10)*100)
  elif(rows[1][2]<20): 
    diff=rows[1][2]-rows[1][1]
    L[1]+=((diff/10)*100)
  elif(rows[1][2]<30):  
    diff=rows[1][2]-rows[1][1]
    L[2]+=((diff/10)*100)
  elif(rows[1][2]<40):  
    diff=rows[1][2]-rows[1][1]
    L[3]+=((diff/10)*100)
  elif(rows[1][2]<50):  
    diff=rows[1][2]-rows[1][1]
    L[4]+=((diff/10)*100)
  elif(rows[1][2]<60):  
    diff=rows[1][2]-rows[1][1]
    L[5]+=((diff/10)*100)
  elif(rows[1][2]<70):  
    diff=rows[1][2]-rows[1][1]
    L[6]+=((diff/10)*100)
  elif(rows[1][2]<80):  
    diff=rows[1][2]-rows[1][1]
    L[7]+=((diff/10)*100)                        
  elif(rows[1][2]<90):  
    diff=rows[1][2]-rows[1][1]
    L[8]+=((diff/10)*100) 
  elif(rows[1][2]<100):  
    diff=rows[1][2]-rows[1][1]
    L[9]+=((diff/10)*100)
x=[i for i in range(1,11,1)]
plt.plot(x,L,label='mef2c-alu+intergenic')

L=[0]*10
for rows in dataset_10.iterrows():
  if(rows[1][2]<10):
    diff=rows[1][2]-rows[1][1]
    L[0]+=((diff/10)*100)
  elif(rows[1][2]<20): 
    diff=rows[1][2]-rows[1][1]
    L[1]+=((diff/10)*100)
  elif(rows[1][2]<30):  
    diff=rows[1][2]-rows[1][1]
    L[2]+=((diff/10)*100)
  elif(rows[1][2]<40):  
    diff=rows[1][2]-rows[1][1]
    L[3]+=((diff/10)*100)
  elif(rows[1][2]<50):  
    diff=rows[1][2]-rows[1][1]
    L[4]+=((diff/10)*100)
  elif(rows[1][2]<60):  
    diff=rows[1][2]-rows[1][1]
    L[5]+=((diff/10)*100)
  elif(rows[1][2]<70):  
    diff=rows[1][2]-rows[1][1]
    L[6]+=((diff/10)*100)
  elif(rows[1][2]<80):  
    diff=rows[1][2]-rows[1][1]
    L[7]+=((diff/10)*100)                        
  elif(rows[1][2]<90):  
    diff=rows[1][2]-rows[1][1]
    L[8]+=((diff/10)*100) 
  elif(rows[1][2]<100):  
    diff=rows[1][2]-rows[1][1]
    L[9]+=((diff/10)*100)
x=[i for i in range(1,11,1)]
plt.plot(x,L,label='mef2c-alu+promotor')

L=[0]*10
for rows in dataset_7.iterrows():
  if(rows[1][2]<10):
    diff=rows[1][2]-rows[1][1]
    L[0]+=((diff/10)*100)
  elif(rows[1][2]<20): 
    diff=rows[1][2]-rows[1][1]
    L[1]+=((diff/10)*100)
  elif(rows[1][2]<30):  
    diff=rows[1][2]-rows[1][1]
    L[2]+=((diff/10)*100)
  elif(rows[1][2]<40):  
    diff=rows[1][2]-rows[1][1]
    L[3]+=((diff/10)*100)
  elif(rows[1][2]<50):  
    diff=rows[1][2]-rows[1][1]
    L[4]+=((diff/10)*100)
  elif(rows[1][2]<60):  
    diff=rows[1][2]-rows[1][1]
    L[5]+=((diff/10)*100)
  elif(rows[1][2]<70):  
    diff=rows[1][2]-rows[1][1]
    L[6]+=((diff/10)*100)
  elif(rows[1][2]<80):  
    diff=rows[1][2]-rows[1][1]
    L[7]+=((diff/10)*100)                        
  elif(rows[1][2]<90):  
    diff=rows[1][2]-rows[1][1]
    L[8]+=((diff/10)*100) 
  elif(rows[1][2]<100):  
    diff=rows[1][2]-rows[1][1]
    L[9]+=((diff/10)*100)
x=[i for i in range(1,11,1)]
plt.plot(x,L,label='mef2c-alu')

plt.grid()
plt.legend()
plt.show()
