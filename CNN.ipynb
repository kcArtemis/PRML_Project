# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
import numpy as np

# %%
from keras.utils import np_utils
import tensorflow as tf

# %%
batch_size = 128
num_classes = 10
epochs = 12
img_rows, img_cols = 28, 28
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
y_train[0].shape
# Out:
# (10,)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/12
# 469/469 [==============================] - 43s 90ms/step - loss: 16.6846 - accuracy: 0.1525 - val_loss: 10.3766 - val_accuracy: 0.2174
# Epoch 2/12
# 469/469 [==============================] - 42s 91ms/step - loss: 7.6709 - accuracy: 0.2944 - val_loss: 5.5195 - val_accuracy: 0.3714
# Epoch 3/12
# 469/469 [==============================] - 42s 90ms/step - loss: 4.6629 - accuracy: 0.4373 - val_loss: 3.6726 - val_accuracy: 0.5017
# Epoch 4/12
# 469/469 [==============================] - 42s 89ms/step - loss: 3.3460 - accuracy: 0.5365 - val_loss: 2.7692 - val_accuracy: 0.5881
# Epoch 5/12
# 469/469 [==============================] - 42s 89ms/step - loss: 2.6199 - accuracy: 0.6036 - val_loss: 2.2307 - val_accuracy: 0.6433
# Epoch 6/12
# 469/469 [==============================] - 42s 90ms/step - loss: 2.1608 - accuracy: 0.6547 - val_loss: 1.8774 - val_accuracy: 0.6871
# Epoch 7/12
# 469/469 [==============================] - 42s 90ms/step - loss: 1.8442 - accuracy: 0.6932 - val_loss: 1.6328 - val_accuracy: 0.7221
# Epoch 8/12
# 469/469 [==============================] - 42s 90ms/step - loss: 1.6147 - accuracy: 0.7222 - val_loss: 1.4490 - val_accuracy: 0.7453
# Epoch 9/12
# 469/469 [==============================] - 42s 90ms/step - loss: 1.4417 - accuracy: 0.7461 - val_loss: 1.3077 - val_accuracy: 0.7670
# Epoch 10/12
# 469/469 [==============================] - 43s 91ms/step - loss: 1.3062 - accuracy: 0.7660 - val_loss: 1.1968 - val_accuracy: 0.7836
# Epoch 11/12
# 469/469 [==============================] - 43s 91ms/step - loss: 1.1980 - accuracy: 0.7825 - val_loss: 1.1066 - val_accuracy: 0.7963
# Epoch 12/12
# 469/469 [==============================] - 43s 91ms/step - loss: 1.1095 - accuracy: 0.7958 - val_loss: 1.0317 - val_accuracy: 0.8083
# Test loss: 1.0316979885101318
# Test accuracy: 0.8083000183105469
