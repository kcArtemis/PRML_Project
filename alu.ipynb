# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('Alu_21.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64811 entries, 0 to 64810
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   chr21    64811 non-null  object
#  1   5010000  64811 non-null  int64
#  2   5010061  64811 non-null  int64
#  3   AluYk11  64811 non-null  object
#  4   465      64811 non-null  int64
#  5   -        64811 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 3.0+ MB

# %%
df = df[df['AluYk11'].str.contains('Alu')]
L=[]
for i in range(len(64811)):
  L.append(i*100)
# Out:
#     chr21  5010000  5010061 AluYk11   465        -
# 2   chr21  5010563  5010892    AluY  2392        -
# 4   chr21  5010955  5011213   AluJb  1590  #ERROR!
# 13  chr21  5018520  5018827   AluJo  2047        -
# 24  chr21  5025498  5025791  AluSx1  2184  #ERROR!
# 25  chr21  5026880  5027179   AluSg  2395        -

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-3c6a894d44d5> in <module>()
# ----> 1 norm.pdf(df)
#
# /usr/local/lib/python3.7/dist-packages/scipy/stats/_distn_infrastructure.py in pdf(self, x, *args, **kwds)
#    1738         args = tuple(map(asarray, args))
#    1739         dtyp = np.find_common_type([x.dtype, np.float64], [])
# -> 1740         x = np.asarray((x - loc)/scale, dtype=dtyp)
#    1741         cond0 = self._argcheck(*args) & (scale > 0)
#    1742         cond1 = self._support_mask(x, *args) & (scale > 0)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
