# %%
import re
import pandas as pd

# %%
with open("MA0009.2.tsv", 'r') as myfile:  
  with open("MA0009.2.csv", 'w') as csv_file:
    for line in myfile:
      fileContent = re.sub("\t", ",", line)
      csv_file.write(fileContent)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8d7b454f3753> in <module>()
# ----> 1 with open("MA0009.2.tsv", 'r') as myfile:
#       2   with open("MA0009.2.csv", 'w') as csv_file:
#       3     for line in myfile:
#       4       fileContent = re.sub("\t", ",", line)
#       5       csv_file.write(fileContent)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MA0009.2.tsv'

# %%
data=pd.read_csv('MA0009.2.csv')
data.head()
# Out:
#    chr1  20030  20046  TBXT  810  415  +
# 0  chr1  20030  20046  TBXT  800  398  -
# 1  chr1  26469  26485  TBXT  924  664  +
# 2  chr1  26469  26485  TBXT  928  675  -
# 3  chr1  33748  33764  TBXT  804  406  +
# 4  chr1  33748  33764  TBXT  804  406  -

# %%
rslt_df = data[data['chr1'] == 'chr21']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-0251bb237b02> in <module>()
#       1 rslt_df = data[data['chr1'] == 'chr21']
#       2 rslt_df.reset_index()
# ----> 3 rslt_df.drop(['index'],axis='columns')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
rslt_df.to_csv(r'/content/drive/MyDrive/Alu_transcriptic_factor data/TBXT.tsv',index=False,sep='\t')
